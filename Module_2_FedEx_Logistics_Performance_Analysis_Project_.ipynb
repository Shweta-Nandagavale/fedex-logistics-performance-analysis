# %% [markdown]
# <a href="https://colab.research.google.com/github/Shweta-Nandagavale/fedex-logistics-performance-analysis/blob/main/Module_2_FedEx_Logistics_Performance_Analysis_Project_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - **FedEx** **Logistics** **Performance** **Analysis**

# %% [markdown]
# **project** **Type** - EDA
#
# **Contribution** - Individual

# %% [markdown]
# **GitHub** **link** -

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The FedEx Logistics Performance Analysis project aims to leverage data analytics to enhance the efficiency, cost-effectiveness, and service quality of FedEx's global logistics and supply chain operations. With a vast network serving millions of shipments daily, FedEx faces constant challenges in optimizing its transportation, warehousing, and workforce management. This project will analyze historical logistics data to identify inefficiencies, bottlenecks, and areas for improvement, ultimately providing actionable insights for better decision-making.
#
# **Key Components:**
# **Data Collection and Preparation:** Historical data from FedEx’s logistics operations, including shipment details, delivery times, transportation costs, resource utilization, and customer feedback, will be gathered. Data cleaning and preprocessing will be carried out to ensure accuracy and consistency.
#
# **Exploratory Data Analysis (EDA):** Initial analysis will identify trends, correlations, and outliers in the logistics data, focusing on KPIs like delivery timeliness, cost per shipment, and resource allocation.
#
# **Performance Evaluation**: Detailed analysis will assess performance across regions, services, and delivery routes, focusing on key areas such as delayed deliveries, cost overruns, and resource inefficiencies.
#
# **Predictive Modeling and Optimization:** Advanced analytical techniques such as machine learning models may be applied to predict future performance, assess risks, and identify optimal strategies for cost reduction and performance improvement.
#
# **Recommendation Development**: Based on the insights derived from the data, actionable recommendations will be made to improve logistics operations, reduce costs, optimize resource usage, and enhance overall service quality.
#
# **Expected Outcomes:**
# Improved understanding of logistics performance drivers.
#
# Identification of areas where operational costs can be reduced without sacrificing service quality.
#
# Data-driven recommendations for optimizing resource allocation and improving delivery efficiency.
#
# Enhanced ability to forecast delivery times and better manage customer expectations.
#
# Support for FedEx’s sustainability goals through improved efficiency and reduced environmental impact.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# FedEx, a global leader in logistics and transportation, faces constant challenges in optimizing its operations, ensuring timely deliveries, and minimizing costs. Despite using advanced technology and large-scale data, inefficiencies still exist in the logistics performance across different regions and service lines.**The dataset aims to optimize FedEx Logistics' global supply chain by providing detailed insights into purchase orders, shipment methods, vendor agreements, and delivery schedules. With the rise of eCommerce and increasing global distribution demands, analyzing this data will help identify bottlenecks, minimize freight costs, and enhance delivery efficiency. The goal is to streamline operations, improve customer satisfaction, and maintain a competitive edge by ensuring timely deliveries and cost-effective logistics management.**
#  The goal of this project is to analyze the logistics performance data of FedEx, identify key performance indicators (KPIs) that impact operational efficiency, and recommend actionable insights to improve overall performance.
# Specific challenges include:
#
# **Delayed** **Deliveries**: Identifying patterns and root causes of delayed deliveries.
#
# **Cost** **Optimization**: Analyzing factors contributing to high operational costs and proposing cost-saving solutions.
#
# **Resource** **Allocation**: Evaluating the allocation and utilization of resources like vehicles, warehouses, and workforce.
#
# **Service** **Level** **Variability**: Investigating differences in service levels across regions or service types.
#
# The analysis will leverage historical data, operational metrics, and performance indicators to provide data-driven insights for enhancing logistics performance, improving customer satisfaction, and driving operational efficiencies.

# %% [markdown]
# #Define Your Business Objective?

# %% [markdown]
# The business objective is to optimize FedEx Logistics' global supply chain operations by leveraging data insights to improve delivery efficiency, reduce shipping costs, and enhance customer satisfaction. The goal is to identify bottlenecks, streamline processes, and ensure timely and cost-effective deliveries across various regions and industries. This will support FedEx in maintaining a competitive edge in the growing eCommerce and global distribution landscape while delivering value to both the company and its customers.
# The primary business objective of the FedEx Logistics Performance Analysis project is to enhance the operational efficiency of FedEx’s global logistics and supply chain network by leveraging data analytics.
# The project aims to:
#
# **Improve Delivery Timeliness**: Analyze delivery patterns to identify bottlenecks and factors leading to delays in shipments. The goal is to develop strategies for reducing delivery times, enhancing on-time performance, and ensuring higher customer satisfaction.
#
# **Reduce Operational Costs**: Identify cost drivers across the logistics and supply chain operations, including transportation, warehousing, and labor. The objective is to uncover opportunities for cost optimization without sacrificing service quality or efficiency.
#
# **Optimize Resource Allocation**: Evaluate the current allocation of resources such as vehicles, personnel, and warehouses. The objective is to recommend strategies for better utilization of these resources, improving throughput while reducing idle times and inefficiencies.
#
# **Enhance Service Consistency**: Identify and address service level variances across different regions and service types. The objective is to ensure that all customers receive a consistent experience, regardless of location or service level chosen.
#
# **Data-Driven Decision Making**: Provide actionable insights and recommendations based on thorough data analysis that will empower FedEx leadership to make informed, strategic decisions for long-term improvements and competitive advantage.
#
# **Support** **Sustainability Initiatives**: Analyze operational data to find ways of minimizing environmental impact, such as reducing fuel consumption or optimizing delivery routes, supporting FedEx’s sustainability goals.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Data link - https://drive.google.com/file/d/1bpq_Dr5To9NfzJsg63f1r8Kc-11ritgV/view?usp=sharing

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv('/content/drive/MyDrive/module2 class learning/SCMS_Delivery_History_Dataset.csv')
data
# Out:
#           ID Project Code            PQ # PO / SO # ASN/DN #        Country  \
# 0          1   100-CI-T01  Pre-PQ Process    SCMS-4    ASN-8  Côte d'Ivoire
# 1          3   108-VN-T01  Pre-PQ Process   SCMS-13   ASN-85        Vietnam
# 2          4   100-CI-T01  Pre-PQ Process   SCMS-20   ASN-14  Côte d'Ivoire
# 3         15   108-VN-T01  Pre-PQ Process   SCMS-78   ASN-50        Vietnam
# 4         16   108-VN-T01  Pre-PQ Process   SCMS-81   ASN-55        Vietnam
# ...      ...          ...             ...       ...      ...            ...
# 10319  86818   103-ZW-T30       FPQ-15197  SO-50020  DN-4307       Zimbabwe
# 10320  86819   104-CI-T30       FPQ-15259  SO-50102  DN-4313  Côte d'Ivoire
# 10321  86821   110-ZM-T30       FPQ-14784  SO-49600  DN-4316         Zambia
# 10322  86822   200-ZW-T30       FPQ-16523  SO-51680  DN-4334       Zimbabwe
# 10323  86823   103-ZW-T30       FPQ-15197  SO-50022  DN-4336       Zimbabwe
#
# ...

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
# by default it gives first 5 rows
data.head()
# Out:
#    ID Project Code            PQ # PO / SO # ASN/DN #        Country  \
# 0   1   100-CI-T01  Pre-PQ Process    SCMS-4    ASN-8  Côte d'Ivoire
# 1   3   108-VN-T01  Pre-PQ Process   SCMS-13   ASN-85        Vietnam
# 2   4   100-CI-T01  Pre-PQ Process   SCMS-20   ASN-14  Côte d'Ivoire
# 3  15   108-VN-T01  Pre-PQ Process   SCMS-78   ASN-50        Vietnam
# 4  16   108-VN-T01  Pre-PQ Process   SCMS-81   ASN-55        Vietnam
#
#   Managed By  Fulfill Via Vendor INCO Term Shipment Mode  ...  \
# 0   PMO - US  Direct Drop              EXW           Air  ...
# 1   PMO - US  Direct Drop              EXW           Air  ...
# 2   PMO - US  Direct Drop              FCA           Air  ...
# 3   PMO - US  Direct Drop              EXW           Air  ...
# 4   PMO - US  Direct Drop              EXW           Air  ...
#
#   Unit of Measure (Per Pack) Line Item Quantity Line Item Value Pack Price  \
# 0                         30                 19           551.0      29.00
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
data.shape
# Out:
# (10324, 33)

# %% [markdown]
# DataSet Consist of 10324 Rows And 33 Columns

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10324 entries, 0 to 10323
# Data columns (total 33 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ID                            10324 non-null  int64
#  1   Project Code                  10324 non-null  object
#  2   PQ #                          10324 non-null  object
#  3   PO / SO #                     10324 non-null  object
#  4   ASN/DN #                      10324 non-null  object
#  5   Country                       10324 non-null  object
#  6   Managed By                    10324 non-null  object
#  7   Fulfill Via                   10324 non-null  object
#  8   Vendor INCO Term              10324 non-null  object
#  9   Shipment Mode                 9964 non-null   object
#  10  PQ First Sent to Client Date  10324 non-null  object
#  11  PO Sent to Vendor Date        10324 non-null  object
# ...

# %%
#checking the null values in column
data.isnull().sum()
# Out:
# ID                                 0
# Project Code                       0
# PQ #                               0
# PO / SO #                          0
# ASN/DN #                           0
# Country                            0
# Managed By                         0
# Fulfill Via                        0
# Vendor INCO Term                   0
# Shipment Mode                    360
# PQ First Sent to Client Date       0
# PO Sent to Vendor Date             0
# Scheduled Delivery Date            0
# Delivered to Client Date           0
# Delivery Recorded Date             0
# Product Group                      0
# Sub Classification                 0
# Vendor                             0
# Item Description                   0
# Molecule/Test Type                 0
# Brand                              0
# Dosage                          1736
# Dosage Form                        0
# Unit of Measure (Per Pack)         0
# Line Item Quantity                 0
# ...

# %% [markdown]
# here we can see that there are nan values Shipment Mode, Dosage, Line Item Insurance in column in data

# %%
data.dropna(inplace=True)

# %%
data.reset_index(inplace=True)
data.isnull().sum()
# Out:
# index                           0
# ID                              0
# Project Code                    0
# PQ #                            0
# PO / SO #                       0
# ASN/DN #                        0
# Country                         0
# Managed By                      0
# Fulfill Via                     0
# Vendor INCO Term                0
# Shipment Mode                   0
# PQ First Sent to Client Date    0
# PO Sent to Vendor Date          0
# Scheduled Delivery Date         0
# Delivered to Client Date        0
# Delivery Recorded Date          0
# Product Group                   0
# Sub Classification              0
# Vendor                          0
# Item Description                0
# Molecule/Test Type              0
# Brand                           0
# Dosage                          0
# Dosage Form                     0
# Unit of Measure (Per Pack)      0
# Line Item Quantity              0
# Line Item Value                 0
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# *here we can see that there is no duplicate values is in DataFrame

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8153    False
# 8154    False
# 8155    False
# 8156    False
# 8157    False
# Length: 8158, dtype: bool

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
data.isnull()
# Out:
#       index     ID  Project Code   PQ #  PO / SO #  ASN/DN #  Country  \
# 0     False  False         False  False      False     False    False
# 1     False  False         False  False      False     False    False
# 2     False  False         False  False      False     False    False
# 3     False  False         False  False      False     False    False
# 4     False  False         False  False      False     False    False
# ...     ...    ...           ...    ...        ...       ...      ...
# 8153  False  False         False  False      False     False    False
# 8154  False  False         False  False      False     False    False
# 8155  False  False         False  False      False     False    False
# 8156  False  False         False  False      False     False    False
# 8157  False  False         False  False      False     False    False
#
#       Managed By  Fulfill Via  Vendor INCO Term  ...  \
# 0          False        False             False  ...
# ...

# %%
data.isnull().sum()
# Out:
# index                           0
# ID                              0
# Project Code                    0
# PQ #                            0
# PO / SO #                       0
# ASN/DN #                        0
# Country                         0
# Managed By                      0
# Fulfill Via                     0
# Vendor INCO Term                0
# Shipment Mode                   0
# PQ First Sent to Client Date    0
# PO Sent to Vendor Date          0
# Scheduled Delivery Date         0
# Delivered to Client Date        0
# Delivery Recorded Date          0
# Product Group                   0
# Sub Classification              0
# Vendor                          0
# Item Description                0
# Molecule/Test Type              0
# Brand                           0
# Dosage                          0
# Dosage Form                     0
# Unit of Measure (Per Pack)      0
# Line Item Quantity              0
# Line Item Value                 0
# ...

# %%
# Visualizing the missing values
sns.heatmap(data.isnull(), cbar = False)
# Out:
# <Axes: >

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Fedex dataset consists of 10,324 entries and 33 columns, including various fields related to procurement and shipment details, such as IDs, project codes, purchase orders, and shipping numbers. It also captures logistical details like shipment modes, vendor terms, and delivery dates. Key numerical fields include line item quantities, prices, and freight costs. Some columns contain missing data, such as "Shipment Mode" and "Dosage," while most others are complete. Additionally, certain fields like "Weight (Kilograms)" and "Freight Cost (USD)" are stored as objects but may need conversion for numerical analysis. Overall, it’s a detailed dataset suited for procurement and supply chain analysis.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
data.columns
# Out:
# Index(['index', 'ID', 'Project Code', 'PQ #', 'PO / SO #', 'ASN/DN #',
#        'Country', 'Managed By', 'Fulfill Via', 'Vendor INCO Term',
#        'Shipment Mode', 'PQ First Sent to Client Date',
#        'PO Sent to Vendor Date', 'Scheduled Delivery Date',
#        'Delivered to Client Date', 'Delivery Recorded Date', 'Product Group',
#        'Sub Classification', 'Vendor', 'Item Description',
#        'Molecule/Test Type', 'Brand', 'Dosage', 'Dosage Form',
#        'Unit of Measure (Per Pack)', 'Line Item Quantity', 'Line Item Value',
#        'Pack Price', 'Unit Price', 'Manufacturing Site',
#        'First Line Designation', 'Weight (Kilograms)', 'Freight Cost (USD)',
#        'Line Item Insurance (USD)'],
#       dtype='object')

# %%
# Dataset Describe
data.describe()
# Out:
#               index            ID  Unit of Measure (Per Pack)  \
# count   8158.000000   8158.000000                 8158.000000
# mean    5718.329370  56644.616573                   80.203972
# std     2942.312944  31253.921647                   81.296579
# min       21.000000    108.000000                    5.000000
# 25%     3173.250000  21990.250000                   30.000000
# 50%     6092.500000  73486.000000                   60.000000
# 75%     8278.750000  84306.750000                   60.000000
# max    10323.000000  86823.000000                 1000.000000
#
#        Line Item Quantity  Line Item Value   Pack Price   Unit Price  \
# count         8158.000000     8.158000e+03  8158.000000  8158.000000
# mean         22091.348492     1.670237e+05    12.408811     0.212851
# std          43990.580533     3.758129e+05    17.059437     0.285822
# min              1.000000     0.000000e+00     0.000000     0.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# **ID:**  Unique identifier for each logistics record.
#
# **Project Code:**  Code representing the project or initiative tied to the shipment.
#
# **PQ #:**  Price Quotation reference number.
#
# **PO/SO #:** Purchase Order or Sales Order associated with the shipment.
#
# **ASN/DN #:**  Advanced Shipment Notice or Delivery Note reference.
#
# **Country:** Destination country for the shipment (e.g., Côte d'Ivoire, Vietnam).
#
# **Managed By:**  Specifies which team manages the project (e.g., PMO-US).
#
# **Fulfill Via:**  Method of fulfillment, such as direct drop shipment.
#
# **Vendor INCO Term:**  Incoterms defining the shipment agreement (e.g., EXW, FCA).
#
# **Shipment Mode:**  The mode of transportation used (e.g., air).
#
# **PQ First Sent to Client Date:**  The date the Price Quotation was first sent to the client (some records indicate "Pre-PQ Process").
#
# **PO Sent to Vendor Date:**  Date the purchase order was sent to the vendor.
#
# **Scheduled Delivery Date:** The planned date for delivery.
#
# **Delivered to Client Date:**  The actual date the shipment was delivered.
#
# **Delivery Recorded Date:**  Date when delivery was recorded.
#
# **Product Group:**  General classification of the product (e.g., HIV test, ARV Pediatric).
#
# **Sub Classification:**  Further categorization of the product.
#
# **Vendor:**  The company supplying the goods (e.g., RANBAXY Fine Chemicals LTD, Aurobindo Pharma Limited).
#
# **Item Description:**  Detailed description of the item being shipped.
#
# **Molecule/Test Type:**  The type of test or pharmaceutical molecule (e.g., HIV, Nevirapine).
#
# **Brand:**  The brand name of the product (e.g., Reveal, Generic).
#
# **Dosage:**  The dosage strength of the pharmaceutical product (if applicable).
#
# **Dosage Form:**  The form in which the product is delivered (e.g., test kit, oral suspension).
#
# **Unit of Measure (Per Pack):**  The number of units per pack.
#
# **Line Item Quantity:**  The total number of units shipped.
#
# **Line Item Value:**  The total value of the line item in the shipment.
#
# **Pack Price:**  Price per pack of the item.
#
# **Unit Price:**  Price per individual unit of the item.
#
# **Manufacturing Site:**  The location where the item was manufactured (e.g., Ranbaxy Fine Chemicals LTD, Aurobindo Unit III, India).
#
# **First Line Designation:**  Indicates whether the product is designated for first-line use.
#
# **Weight (Kilograms):**  The weight of the shipment.
#
# **Freight Cost (USD):**  The cost of shipping the item in U.S. dollars.
#
# **Line Item Insurance (USD):**  Insurance cost for the line item, if applicable.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
data.nunique()
# Out:
# index                           8158
# ID                              8158
# Project Code                      90
# PQ #                             877
# PO / SO #                       4750
# ASN/DN #                        5242
# Country                           34
# Managed By                         2
# Fulfill Via                        2
# Vendor INCO Term                   7
# Shipment Mode                      4
# PQ First Sent to Client Date     581
# PO Sent to Vendor Date           565
# Scheduled Delivery Date         1630
# Delivered to Client Date        1743
# Delivery Recorded Date          1676
# Product Group                      3
# Sub Classification                 4
# Vendor                            42
# Item Description                 136
# Molecule/Test Type                41
# Brand                             25
# Dosage                            53
# Dosage Form                       15
# Unit of Measure (Per Pack)        21
# ...

# %%
for i in data.columns:
  print("No. of unique values in ",i,"is",data[i].nunique(),".")
# Out:
# No. of unique values in  ID is 10324 .
# No. of unique values in  Project Code is 142 .
# No. of unique values in  PQ # is 1237 .
# No. of unique values in  PO / SO # is 6233 .
# No. of unique values in  ASN/DN # is 7030 .
# No. of unique values in  Country is 43 .
# No. of unique values in  Managed By is 4 .
# No. of unique values in  Fulfill Via is 2 .
# No. of unique values in  Vendor INCO Term is 8 .
# No. of unique values in  Shipment Mode is 4 .
# No. of unique values in  PQ First Sent to Client Date is 765 .
# No. of unique values in  PO Sent to Vendor Date is 897 .
# No. of unique values in  Scheduled Delivery Date is 2006 .
# No. of unique values in  Delivered to Client Date is 2093 .
# No. of unique values in  Delivery Recorded Date is 2042 .
# No. of unique values in  Product Group is 5 .
# No. of unique values in  Sub Classification is 6 .
# No. of unique values in  Vendor is 73 .
# No. of unique values in  Item Description is 184 .
# ...

# %%
data.loc[:,'First Line Designation'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
data.loc[:,'Fulfill Via'].unique()
# Out:
# array(['Direct Drop', 'From RDC'], dtype=object)

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

# %%
#convert Country into uppercase using lambda function
data.loc[:,'Country']=data.loc[:,'Country'].apply(lambda x: x.upper())
data.head()
# Out:
#    ID Project Code            PQ # PO / SO # ASN/DN #        Country  \
# 0   1   100-CI-T01  Pre-PQ Process    SCMS-4    ASN-8  CÔTE D'IVOIRE
# 1   3   108-VN-T01  Pre-PQ Process   SCMS-13   ASN-85        VIETNAM
# 2   4   100-CI-T01  Pre-PQ Process   SCMS-20   ASN-14  CÔTE D'IVOIRE
# 3  15   108-VN-T01  Pre-PQ Process   SCMS-78   ASN-50        VIETNAM
# 4  16   108-VN-T01  Pre-PQ Process   SCMS-81   ASN-55        VIETNAM
#
#   Managed By  Fulfill Via Vendor INCO Term Shipment Mode  ...  \
# 0   PMO - US  Direct Drop              EXW           Air  ...
# 1   PMO - US  Direct Drop              EXW           Air  ...
# 2   PMO - US  Direct Drop              FCA           Air  ...
# 3   PMO - US  Direct Drop              EXW           Air  ...
# 4   PMO - US  Direct Drop              EXW           Air  ...
#
#   Unit of Measure (Per Pack) Line Item Quantity Line Item Value Pack Price  \
# 0                         30                 19           551.0      29.00
# ...

# %%
#round Line Item Value values to decimal places
data.loc[:,'Line Item Value_new']=data.loc[:,'Line Item Value'].apply(lambda x: round(x,2))
data.head(5)
# Out:
#    ID Project Code            PQ # PO / SO # ASN/DN #        Country  \
# 0   1   100-CI-T01  Pre-PQ Process    SCMS-4    ASN-8  CÔTE D'IVOIRE
# 1   3   108-VN-T01  Pre-PQ Process   SCMS-13   ASN-85        VIETNAM
# 2   4   100-CI-T01  Pre-PQ Process   SCMS-20   ASN-14  CÔTE D'IVOIRE
# 3  15   108-VN-T01  Pre-PQ Process   SCMS-78   ASN-50        VIETNAM
# 4  16   108-VN-T01  Pre-PQ Process   SCMS-81   ASN-55        VIETNAM
#
#   Managed By  Fulfill Via Vendor INCO Term Shipment Mode  ...  \
# 0   PMO - US  Direct Drop              EXW           Air  ...
# 1   PMO - US  Direct Drop              EXW           Air  ...
# 2   PMO - US  Direct Drop              FCA           Air  ...
# 3   PMO - US  Direct Drop              EXW           Air  ...
# 4   PMO - US  Direct Drop              EXW           Air  ...
#
#   Line Item Quantity Line Item Value Pack Price Unit Price  \
# 0                 19           551.0      29.00       0.97
# ...

# %%
# Convert 'Freight Cost (USD)' to numeric, handling errors
data['Freight Cost (USD)'] = pd.to_numeric(data['Freight Cost (USD)'], errors='coerce')

# Now you can perform the groupby and aggregation
data.groupby('Country').agg({'Freight Cost (USD)':['mean','count','sum']})
# Out:
#                    Freight Cost (USD)
#                                  mean count          sum
# Country
# AFGHANISTAN                540.525000     2      1081.05
# ANGOLA                    4685.242857     7     32796.70
# BELIZE                    1959.610000     1      1959.61
# BENIN                     9430.738571     7     66015.17
# BOTSWANA                  2224.680161    62    137930.17
# BURKINA FASO                      NaN     0         0.00
# BURUNDI                   5572.184286    56    312042.32
# CAMEROON                 32006.276607    56   1792351.49
# CONGO, DRC                6721.951058   104    699082.91
# CÔTE D'IVOIRE             8356.879986   729   6092165.51
# DOMINICAN REPUBLIC        8780.877857    28    245864.58
# ETHIOPIA                 11658.745965   171   1993645.56
# GHANA                    13162.594762    42    552828.98
# GUATEMALA                 7698.996000     5     38494.98
# GUINEA                    1804.200000     1      1804.20
# ...

# %%
#no.of shipping across different countries
d1 = (data.groupby('Country')['ID'].count().reset_index()).sort_values('ID',ascending=False,ignore_index=True)
d1.columns = ['Country','#ofshipping']
d1
# Out:
#                Country  #ofshipping
# 0         SOUTH AFRICA         1406
# 1              NIGERIA         1194
# 2        CÔTE D'IVOIRE         1083
# 3               UGANDA          779
# 4              VIETNAM          688
# 5               ZAMBIA          683
# 6                HAITI          655
# 7           MOZAMBIQUE          631
# 8             ZIMBABWE          538
# 9             TANZANIA          519
# 10              RWANDA          430
# 11          CONGO, DRC          333
# 12              GUYANA          237
# 13            ETHIOPIA          216
# 14         SOUTH SUDAN          164
# 15               KENYA          111
# 16             BURUNDI           98
# 17             NAMIBIA           95
# 18            CAMEROON           75
# 19            BOTSWANA           70
# 20               GHANA           58
# 21  DOMINICAN REPUBLIC           52
# 22               SUDAN           46
# 23           SWAZILAND           35
# 24                MALI           17
# ...

# %%
#which shipment mostly used
d2 = (data.groupby('Shipment Mode')['ID'].count().reset_index()).sort_values('ID',ascending=False,ignore_index=True)
d2.columns = ['Shipment Mode','#times']
d2['#times(%)'] = d2['#times'].apply(lambda x: x/data.shape[0]*100)
d2
# Out:
#   Shipment Mode  #times  #times(%)
# 0           Air    6113  59.211546
# 1         Truck    2830  27.411856
# 2   Air Charter     650   6.296009
# 3         Ocean     371   3.593568

# %%
# country vs freightcost
#data['Freight Cost (USD)'] = pd.to_numeric(data['Freight Cost (USD)'], errors='coerce')

d3 = (data.groupby('Country')['Freight Cost (USD)'].mean().round(2).reset_index()).sort_values('Freight Cost (USD)',ascending=False,ignore_index=True).head(5)
d3.columns = ['Country','avg FreightCost(USD)']
d3
# Out:
#         Country  avg FreightCost(USD)
# 0      CAMEROON              32006.28
# 1       NIGERIA              18676.11
# 2  SIERRA LEONE              18249.26
# 3        RWANDA              16838.55
# 4         KENYA              15703.42

# %%
data['Freight Cost (USD)'] = pd.to_numeric(data['Freight Cost (USD)'], errors='coerce')
d4 = (data.groupby('Country')['Freight Cost (USD)'].mean().round(2).reset_index()).sort_values('Freight Cost (USD)',ascending=True,ignore_index=True).head(5)
d4.columns = ['Country','avg FreightCost(USD)']
d4
# Out:
#    Country  avg FreightCost(USD)
# 0  Senegal                722.32
# 1   Guinea               1804.20
# 2   Belize               1959.61
# 3  Liberia               3325.14
# 4   Angola               4685.24

# %%
data.groupby('Country').agg({'Freight Cost (USD)':['mean','max','min']})
# Out:
#                    Freight Cost (USD)
#                                  mean        max      min
# Country
# AFGHANISTAN                540.525000     555.49   525.56
# ANGOLA                    4685.242857   13790.10   840.17
# BELIZE                    1959.610000    1959.61  1959.61
# BENIN                     9430.738571   28541.79  1136.37
# BOTSWANA                  2224.680161   23796.98   304.76
# BURKINA FASO                      NaN        NaN      NaN
# BURUNDI                   5572.184286   33228.68    29.21
# CAMEROON                 32006.276607  123945.00   549.16
# CONGO, DRC                6721.951058   62196.13    91.42
# CÔTE D'IVOIRE             8356.879986   60432.88    22.29
# DOMINICAN REPUBLIC        8780.877857   90360.12   483.68
# ETHIOPIA                 11658.745965  161962.32   114.22
# GHANA                    13162.594762   38560.67   226.25
# GUATEMALA                 7698.996000   20805.80   209.37
# ...

# %%
data.groupby('Country')['Line Item Quantity'].mean()
# Out:
# Country
# AFGHANISTAN               38.333333
# ANGOLA                   440.000000
# BELIZE                   300.000000
# BENIN                  13424.500000
# BOTSWANA               35465.666667
# BURKINA FASO              82.500000
# BURUNDI                 2407.166667
# CAMEROON               32768.703704
# CONGO, DRC              1930.363265
# CÔTE D'IVOIRE          13076.886336
# DOMINICAN REPUBLIC      4683.108108
# ETHIOPIA               15501.543307
# GHANA                  22354.586207
# GUATEMALA               3697.800000
# GUYANA                   807.919753
# HAITI                   9369.559199
# KENYA                   2967.500000
# LEBANON                  117.000000
# LIBYA                   3406.375000
# MALAWI                125000.000000
# MOZAMBIQUE             37067.260870
# NAMIBIA                19556.466667
# NIGERIA                34557.509454
# RWANDA                 25214.095238
# SENEGAL                  100.000000
# SOUTH AFRICA           16847.768328
# ...

# %%
data.groupby('Country').count()
# Out:
#                     index    ID  Project Code  PQ #  PO / SO #  ASN/DN #  \
# Country
# AFGHANISTAN             3     3             3     3          3         3
# ANGOLA                  3     3             3     3          3         3
# BELIZE                  1     1             1     1          1         1
# BENIN                  10    10            10    10         10        10
# BOTSWANA                3     3             3     3          3         3
# BURKINA FASO            2     2             2     2          2         2
# BURUNDI                72    72            72    72         72        72
# CAMEROON               54    54            54    54         54        54
# CONGO, DRC            245   245           245   245        245       245
# CÔTE D'IVOIRE         827   827           827   827        827       827
# DOMINICAN REPUBLIC     37    37            37    37         37        37
# ETHIOPIA              127   127           127   127        127       127
# ...

# %%
# Create data_Country DataFrame:
data_Country = data.groupby('Country').count()

# Create data_Line_Item_Quantity DataFrame:
data_Line_Item_Quantity = data.groupby('Country')['Line Item Quantity'].mean().reset_index()

# Now perform the merge:
result = pd.merge(data_Country, data_Line_Item_Quantity, on='Country', how='outer')

# Display the first few rows to check the result
print(result.head())
# Out:
#        Country  index  ID  Project Code  PQ #  PO / SO #  ASN/DN #  \
# 0  AFGHANISTAN      3   3             3     3          3         3
# 1       ANGOLA      3   3             3     3          3         3
# 2       BELIZE      1   1             1     1          1         1
# 3        BENIN     10  10            10    10         10        10
# 4     BOTSWANA      3   3             3     3          3         3
#
#    Managed By  Fulfill Via  Vendor INCO Term  ...  Line Item Value  \
# 0           3            3                 3  ...                3
# 1           3            3                 3  ...                3
# 2           1            1                 1  ...                1
# 3          10           10                10  ...               10
# 4           3            3                 3  ...                3
#
#    Pack Price  Unit Price  Manufacturing Site  First Line Designation  \
# 0           3           3                   3                       3
# ...

# %%
# Convert 'Freight Cost (USD)' to numeric, handling errors
data['Freight Cost (USD)'] = pd.to_numeric(data['Freight Cost (USD)'], errors='coerce')

# Perform the groupby and aggregation
data_Country = data.groupby('Country').count()  # Counts non-NA values in each column by 'Country'
data_Freight_Cost__USD_ = data.groupby('Country').agg({'Freight Cost (USD)': ['mean', 'count', 'sum']})

# Flatten the multi-level columns in data_Freight_Cost__USD_ for easier merging
data_Freight_Cost__USD_.columns = ['Freight Cost (USD) Mean', 'Freight Cost (USD) Count', 'Freight Cost (USD) Sum']

# Now you can merge the DataFrames
result = pd.merge(data_Country, data_Freight_Cost__USD_, on='Country', how='inner')

# If you want to inspect the result:
print(result)
# Out:
#                     index    ID  Project Code  PQ #  PO / SO #  ASN/DN #  \
# Country
# AFGHANISTAN             3     3             3     3          3         3
# ANGOLA                  3     3             3     3          3         3
# BELIZE                  1     1             1     1          1         1
# BENIN                  10    10            10    10         10        10
# BOTSWANA                3     3             3     3          3         3
# BURKINA FASO            2     2             2     2          2         2
# BURUNDI                72    72            72    72         72        72
# CAMEROON               54    54            54    54         54        54
# CONGO, DRC            245   245           245   245        245       245
# CÔTE D'IVOIRE         827   827           827   827        827       827
# DOMINICAN REPUBLIC     37    37            37    37         37        37
# ETHIOPIA              127   127           127   127        127       127
# ...

# %%
#missing values
data.isnull().sum()
# Out:
# index                              0
# ID                                 0
# Project Code                       0
# PQ #                               0
# PO / SO #                          0
# ASN/DN #                           0
# Country                            0
# Managed By                         0
# Fulfill Via                        0
# Vendor INCO Term                   0
# Shipment Mode                      0
# PQ First Sent to Client Date       0
# PO Sent to Vendor Date             0
# Scheduled Delivery Date            0
# Delivered to Client Date           0
# Delivery Recorded Date             0
# Product Group                      0
# Sub Classification                 0
# Vendor                             0
# Item Description                   0
# Molecule/Test Type                 0
# Brand                              0
# Dosage                             0
# Dosage Form                        0
# Unit of Measure (Per Pack)         0
# ...

# %%
data.isnull()
# Out:
#       index     ID  Project Code   PQ #  PO / SO #  ASN/DN #  Country  \
# 0     False  False         False  False      False     False    False
# 1     False  False         False  False      False     False    False
# 2     False  False         False  False      False     False    False
# 3     False  False         False  False      False     False    False
# 4     False  False         False  False      False     False    False
# ...     ...    ...           ...    ...        ...       ...      ...
# 8153  False  False         False  False      False     False    False
# 8154  False  False         False  False      False     False    False
# 8155  False  False         False  False      False     False    False
# 8156  False  False         False  False      False     False    False
# 8157  False  False         False  False      False     False    False
#
#       Managed By  Fulfill Via  Vendor INCO Term  ...  Line Item Quantity  \
# ...

# %%
data.dropna()
# Out:
#       index     ID Project Code            PQ #   PO / SO #  ASN/DN #  \
# 1        22    115   108-VN-T01  Pre-PQ Process    SCMS-753   ASN-781
# 2        23    116   108-VN-T01  Pre-PQ Process    SCMS-759   ASN-632
# 3        29    161   117-ET-T01  Pre-PQ Process  SCMS-11070   ASN-916
# 4        32    269   108-VN-T01  Pre-PQ Process  SCMS-14190  ASN-1192
# 5        33    270   108-VN-T01  Pre-PQ Process  SCMS-14200  ASN-1171
# ...     ...    ...          ...             ...         ...       ...
# 8139  10305  86802   111-MZ-T30       FPQ-15195    SO-50130   DN-4235
# 8140  10306  86803   111-MZ-T30       FPQ-14843    SO-49721   DN-4236
# 8144  10310  86808   114-UG-T30       FPQ-15294    SO-50070   DN-4259
# 8149  10315  86814   151-NG-T30       FPQ-14989    SO-51424   DN-4276
# 8150  10316  86815   151-NG-T30       FPQ-16313    SO-51420   DN-4279
#
#          Country Managed By  Fulfill Via Vendor INCO Term  ...  \
# ...

# %%
data.dropna()
data['Dosage']=data['Dosage'].fillna(data['Dosage'].mode()[0])

# %%
data.isnull().sum()
# Out:
# index                              0
# ID                                 0
# Project Code                       0
# PQ #                               0
# PO / SO #                          0
# ASN/DN #                           0
# Country                            0
# Managed By                         0
# Fulfill Via                        0
# Vendor INCO Term                   0
# Shipment Mode                      0
# PQ First Sent to Client Date       0
# PO Sent to Vendor Date             0
# Scheduled Delivery Date            0
# Delivered to Client Date           0
# Delivery Recorded Date             0
# Product Group                      0
# Sub Classification                 0
# Vendor                             0
# Item Description                   0
# Molecule/Test Type                 0
# Brand                              0
# Dosage                             0
# Dosage Form                        0
# Unit of Measure (Per Pack)         0
# ...

# %%
data.dropna()
data['Shipment Mode']=data['Shipment Mode'].fillna(data['Shipment Mode'].mode()[0])

# %%
data.dropna()
data['Freight Cost (USD)']=data['Freight Cost (USD)'].fillna(data['Freight Cost (USD)'].mode()[0])

# %%
data.dropna()
data['Line Item Insurance (USD)']=data['Line Item Insurance (USD)'].fillna(data['Line Item Insurance (USD)'].mode()[0])

# %%
data.isnull().sum()
# Out:
# index                           0
# ID                              0
# Project Code                    0
# PQ #                            0
# PO / SO #                       0
# ASN/DN #                        0
# Country                         0
# Managed By                      0
# Fulfill Via                     0
# Vendor INCO Term                0
# Shipment Mode                   0
# PQ First Sent to Client Date    0
# PO Sent to Vendor Date          0
# Scheduled Delivery Date         0
# Delivered to Client Date        0
# Delivery Recorded Date          0
# Product Group                   0
# Sub Classification              0
# Vendor                          0
# Item Description                0
# Molecule/Test Type              0
# Brand                           0
# Dosage                          0
# Dosage Form                     0
# Unit of Measure (Per Pack)      0
# Line Item Quantity              0
# Line Item Value                 0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8158 entries, 0 to 8157
# Data columns (total 35 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   index                         8158 non-null   int64
#  1   ID                            8158 non-null   int64
#  2   Project Code                  8158 non-null   object
#  3   PQ #                          8158 non-null   object
#  4   PO / SO #                     8158 non-null   object
#  5   ASN/DN #                      8158 non-null   object
#  6   Country                       8158 non-null   object
#  7   Managed By                    8158 non-null   object
#  8   Fulfill Via                   8158 non-null   object
#  9   Vendor INCO Term              8158 non-null   object
#  10  Shipment Mode                 8158 non-null   object
#  11  PQ First Sent to Client Date  8158 non-null   object
# ...

# %%
# check the Duplicate
data.duplicated()
data.head()
# Out:
#    index   ID Project Code            PQ #   PO / SO #  ASN/DN #  \
# 0     21  108   104-CI-T01  Pre-PQ Process    SCMS-698   ASN-727
# 1     22  115   108-VN-T01  Pre-PQ Process    SCMS-753   ASN-781
# 2     23  116   108-VN-T01  Pre-PQ Process    SCMS-759   ASN-632
# 3     29  161   117-ET-T01  Pre-PQ Process  SCMS-11070   ASN-916
# 4     32  269   108-VN-T01  Pre-PQ Process  SCMS-14190  ASN-1192
#
#          Country Managed By  Fulfill Via Vendor INCO Term  ...  \
# 0  CÔTE D'IVOIRE   PMO - US  Direct Drop              CIP  ...
# 1        VIETNAM   PMO - US  Direct Drop              EXW  ...
# 2        VIETNAM   PMO - US  Direct Drop              FCA  ...
# 3       ETHIOPIA   PMO - US  Direct Drop              EXW  ...
# 4        VIETNAM   PMO - US  Direct Drop              EXW  ...
#
#   Line Item Quantity Line Item Value Pack Price Unit Price  \
# 0               5513        140581.5      25.50       0.42
# 1               1000          1920.0       1.92       0.01
# ...

# %%
# Check The Duplicate Row
duplicates= data.duplicated().sum()
print(f"Number of duplicates:{duplicates}")
# Out:
# Number of duplicates:0

# %%
# Convert object datatype into datetime and numeric (integer/float)
num_col = ['Weight (Kilograms)','Freight Cost (USD)','Line Item Insurance (USD)']
for i in num_col:
  data[i]=pd.to_numeric(data[i],errors='coerce') # Changed 'corece' to 'coerce'

date_col =['PO Sent to Vendor Date','Scheduled Delivery Date','Delivered to Client Date']
for i in date_col:
  data[i]=pd.to_datetime(data[i],errors='coerce')
# Out:
# <ipython-input-40-4cc9d432f323>:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data[i]=pd.to_datetime(data[i],errors='coerce')
# <ipython-input-40-4cc9d432f323>:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data[i]=pd.to_datetime(data[i],errors='coerce')
# <ipython-input-40-4cc9d432f323>:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data[i]=pd.to_datetime(data[i],errors='coerce')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8158 entries, 0 to 8157
# Data columns (total 35 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   index                         8158 non-null   int64
#  1   ID                            8158 non-null   int64
#  2   Project Code                  8158 non-null   object
#  3   PQ #                          8158 non-null   object
#  4   PO / SO #                     8158 non-null   object
#  5   ASN/DN #                      8158 non-null   object
#  6   Country                       8158 non-null   object
#  7   Managed By                    8158 non-null   object
#  8   Fulfill Via                   8158 non-null   object
#  9   Vendor INCO Term              8158 non-null   object
#  10  Shipment Mode                 8158 non-null   object
#  11  PQ First Sent to Client Date  8158 non-null   object
# ...

# %%
data.head()
# Out:
#    index   ID Project Code            PQ #   PO / SO #  ASN/DN #  \
# 0     21  108   104-CI-T01  Pre-PQ Process    SCMS-698   ASN-727
# 1     22  115   108-VN-T01  Pre-PQ Process    SCMS-753   ASN-781
# 2     23  116   108-VN-T01  Pre-PQ Process    SCMS-759   ASN-632
# 3     29  161   117-ET-T01  Pre-PQ Process  SCMS-11070   ASN-916
# 4     32  269   108-VN-T01  Pre-PQ Process  SCMS-14190  ASN-1192
#
#          Country Managed By  Fulfill Via Vendor INCO Term  ...  \
# 0  CÔTE D'IVOIRE   PMO - US  Direct Drop              CIP  ...
# 1        VIETNAM   PMO - US  Direct Drop              EXW  ...
# 2        VIETNAM   PMO - US  Direct Drop              FCA  ...
# 3       ETHIOPIA   PMO - US  Direct Drop              EXW  ...
# 4        VIETNAM   PMO - US  Direct Drop              EXW  ...
#
#   Line Item Quantity Line Item Value Pack Price Unit Price  \
# 0               5513        140581.5      25.50       0.42
# 1               1000          1920.0       1.92       0.01
# ...

# %%
# Ensure columns are in datetime format before calculating difference
data['Delivered to Client Date'] = pd.to_datetime(data['Delivered to Client Date'], errors='coerce')
data['Scheduled Delivery Date'] = pd.to_datetime(data['Scheduled Delivery Date'], errors='coerce')

# Calculate 'Delivery_time' after ensuring datetime format
data['Delivery_time'] = (data['Delivered to Client Date'] - data['Scheduled Delivery Date']).dt.days

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8158 entries, 0 to 8157
# Data columns (total 36 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   index                         8158 non-null   int64
#  1   ID                            8158 non-null   int64
#  2   Project Code                  8158 non-null   object
#  3   PQ #                          8158 non-null   object
#  4   PO / SO #                     8158 non-null   object
#  5   ASN/DN #                      8158 non-null   object
#  6   Country                       8158 non-null   object
#  7   Managed By                    8158 non-null   object
#  8   Fulfill Via                   8158 non-null   object
#  9   Vendor INCO Term              8158 non-null   object
#  10  Shipment Mode                 8158 non-null   object
#  11  PQ First Sent to Client Date  8158 non-null   object
# ...

# %%
# Write your code to make your dataset analysis ready.
data = data[[
    'Country',
    'Managed By',
    'Fulfill Via',
    'Shipment Mode',
    'PQ First Sent to Client Date',
    'PO Sent to Vendor Date',
    'Scheduled Delivery Date',
    'Delivered to Client Date',
    'Delivery Recorded Date',
    'Line Item Quantity',
    'Line Item Value',
    'Weight (Kilograms)',
    'Freight Cost (USD)',
    'Vendor',
    'Line Item Insurance (USD)'
]]

shipment_mode_mode = data['Shipment Mode'].mode()[0]  # Get the most common value
data['Shipment Mode'].fillna(shipment_mode_mode, inplace=True)  # Fill with the mode


data['Line Item Insurance (USD'] = data['Line Item Insurance (USD)'].fillna(0)  # Fill with 0


data.drop_duplicates(inplace=True)


date_columns = ['PQ First Sent to Client Date', 'PO Sent to Vendor Date',
                'Scheduled Delivery Date', 'Delivered to Client Date',
                'Delivery Recorded Date']
for col in date_columns:
    data[col] = pd.to_datetime(data[col], errors='coerce')  # Convert to datetime, coerce errors


numeric_columns = ['Line Item Quantity', 'Line Item Value', 'Weight (Kilograms)',
                   'Freight Cost (USD)', 'Line Item Insurance (USD)']
for col in numeric_columns:
    data[col] = pd.to_numeric(data[col], errors='coerce')  # Ensure numeric type


data['Country'] = data['Country'].str.strip().str.lower()  # Example normalization

# Check the cleaned data
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 475 entries, 2007-10-02 to 2014-09-19
# Data columns (total 16 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Country                       475 non-null    object
#  1   Managed By                    475 non-null    object
#  2   Fulfill Via                   475 non-null    object
#  3   Shipment Mode                 475 non-null    object
#  4   PQ First Sent to Client Date  382 non-null    datetime64[ns]
#  5   PO Sent to Vendor Date        135 non-null    datetime64[ns]
#  6   Scheduled Delivery Date       475 non-null    datetime64[ns]
#  7   Delivered to Client Date      475 non-null    datetime64[ns]
#  8   Delivery Recorded Date        475 non-null    datetime64[ns]
#  9   Line Item Quantity            475 non-null    int64
#  10  Line Item Value               475 non-null    float64
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# In a FedEx Logistics Performance Analysis project, data wrangling and exploratory data analysis (EDA) are critical steps to ensure the data is clean, well-structured, and ready for analysis. Below is an overview of typical manipulations and insights that may be found during the project:
#
# **Missing** **Data** **Handling**:Identifying columns with missing values and deciding how to handle them (either through imputation, removal, or other techniques).
#
# **Outlier** **Detection**:Identifying outliers in key metrics like delivery times, costs, or distances using statistical methods (e.g., Z-scores, IQR) or visualization (boxplots).
# Outliers could indicate data entry errors or exceptional situations that require special handling.
#
# **Date**/**Time** **Formatting**:Converting date and time fields into a consistent format for analysis (e.g., ensuring timestamps are in the correct timezone, creating new features such as "day of the week" or "hour of the day").
# This helps in understanding how performance may vary across time periods.
#
# **Data** **Type** **Conversion**:Ensuring that numerical data is in the correct format (e.g., converting delivery costs or weights from strings to float or integer types).
# Correctly formatting categorical variables (e.g., regions, delivery methods) for modeling or analysis.
#
# **Normalization**/**Standardization**: Rescaling numerical data like delivery time, distance, or costs to bring different units to the same scale.
# This is particularly important when working with machine learning models or comparing multiple performance metrics.
#
# **Categorical** **Data** **Encoding**:
# Converting categorical variables (e.g., "delivery type," "region") into numerical format using techniques like one-hot encoding, label encoding, or similar, if required for modeling.
#
# **Merging** **Datasets**:Joining multiple data sources (e.g., operational data, customer data, geographical data) to create a unified dataset that provides a holistic view of the logistics performance.
#
# **Insights**
#
# **Regional Performance Variations:** Certain regions may have slower delivery times, which could be due to factors such as road conditions, weather, or local infrastructure. Identifying such regions can lead to targeted interventions.
#
# **Cost Inefficiencies:** You might uncover specific delivery routes or service types that are significantly more expensive than others. This could indicate inefficiencies or areas where cost-cutting measures could be implemented without compromising service quality.
#
# **Seasonal Trends:** Delivery times and costs might fluctuate seasonally (e.g., during holidays, peak shopping seasons). Recognizing these patterns can help in resource planning and optimizing logistics during high-demand periods.
#
# **Impact of Time of Day:** Delivery times could be faster or slower depending on the time of day. For example, deliveries made during peak traffic hours may be delayed, whereas deliveries during off-peak hours might be more efficient.
#
# **Delivery Type Preferences:** If certain types of deliveries have consistently higher performance in terms of speed, cost, or customer satisfaction, this could suggest opportunities for further optimization.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# #### Count of Shipments by Country

# %%
# Chart - 1 visualization code
fig,ax = plt.subplots(1,1,figsize = (8,8))
sns.countplot(x='Country', data=data, color = "skyblue")
plt.title('Count of Shipment By Country')
plt.xlabel('Country')
plt.ylabel('count')
plt.xticks(rotation=90)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here’s why the countplot was chosen for this scenario:
#
# Understanding Shipment Distribution:
# A **countplot** is ideal for visualizing the frequency of categorical data, in this case, the number of shipments by country. The sns.countplot function automatically creates a bar plot that shows how many times each category (here, each country) appears in the dataset. This gives a clear visual of which countries are sending the most shipments.
#
# **Top 20 Countries:** index part ensures that you're focusing on the top 20 countries with the most shipments. This is great for avoiding cluttering the plot with too many less relevant countries (if there are a lot of unique countries in your data). By limiting to the top 20, you get a clearer view of the most significant data points.
# Tight Layout ensures the elements of the plot don’t overlap, which is particularly helpful when displaying long country names or large datasets.
#
# Overall, the countplot is a good choice for this type of categorical comparison and gives an immediate understanding of the distribution of shipments across countries.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **insight**=
# Based on the shipment count, it's evident that South African countries lead with the highest volume of consignments being shipped. This suggests a strong demand or active trade routes within that region, potentially driven by industries such as mining, agriculture, and manufacturing.Following closely behind are Nigeria and Cote d Ivoire, and at least are Zimbabwe and Tanzania which also see significant shipment activity. Vietnam's position could be due to its role as a manufacturing hub in Southeast Asia, while Zimbabwe's shipments might be related to its exports in mining, agriculture, or other key commodities. This trend indicates a diverse global trade landscape with strong regional markets.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive** **Impact**: The insights can lead to optimized marketing, stronger logistics, and better strategic focus on high-growth markets.
#
# **Negative** **Impact**: Over-reliance on specific markets, underperformance in others, or inefficient resource allocation could hinder growth and expose the business to risks.
#
# To make this actionable, it’s crucial to delve deeper into regions with both high and low shipment counts to better understand the underlying factors and adjust business strategies accordingly.

# %% [markdown]
# #### Chart - 2

# %% [markdown]
# #### Distribution of Shipment Modes

# %%
# Calculate the Shipment mode counts
Shipment_mode_counts = data['Shipment Mode'].value_counts()

# Create the pie chart
fig, ax = plt.subplots(figsize=(6, 6))

explode = [0.1 if i == 1 else 0 for i in range(len(Shipment_mode_counts))]
c1 =['pink','blue','brown','yellow']

# Plot the pie chart
ax.pie(Shipment_mode_counts,
       labels=Shipment_mode_counts.index,
       colors=c1,
       explode=explode,
       autopct='%.0f%%',
       startangle=90)
ax.set_title('Shipment Mode Distribution', fontsize=14)
fig.text(0.5, 0.92, 'Analyzing the distribution of shipment mode', ha='center', fontsize=12)


plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# working with categorical data (the different shipment modes). Pie charts are designed for showing how different parts make up the whole in a simple and visually engaging way.
# The value_counts() function provides the frequency of each category in your dataset. This frequency distribution makes it ideal for a pie chart, where each slice represents the percentage of each category relative to the total.
#
# A **pie chart** visually displays the proportionality of each category. Since you are analyzing the relative share of each shipment mode, the chart provides an immediate sense of how much each mode contributes to the total distribution.
#
# **pie charts** are typically used for showing a single categorical breakdown, they are particularly useful when you want to compare the proportions visually. If you're simply trying to show what share each mode has, the pie chart works well.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **insight**
#
# It is clear that more than 63% of consignments are delivered by air, indicating a strong preference
# for this mode of transportation, likely due to its speed and efficiency.
# Following air transport, trucking accounts for 27% of the deliveries,
# suggesting that it plays a significant role in domestic distribution or
# shorter regional routes. Ocean freight, at 4%, is the least utilized method, which may
# reflect longer delivery times and logistical challenges associated with shipping by sea.
# Additionally, air charter services make up 5% of the total,
# which may be used for specialized shipments requiring rapid delivery.
# This distribution highlights the varying needs and priorities in logistics,
# with air transport being the dominant choice for time-sensitive consignments.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive**: If the pie chart shows that Sea shipments are underutilized but are the most cost-efficient option for the business, focusing on shifting more shipments to Sea could result in cost savings and better use of available resources, leading to positive growth.
#
# **Negative**: If Air shipments dominate but have high associated costs, and the customers aren’t demanding faster deliveries, this could lead to unnecessary overhead and lower profit margins. A business might want to reconsider the reliance on air freight and explore more economical options.
#
# the pie chart will provide valuable insights that could drive decisions leading to both positive and negative business outcomes depending on the interpretation of the data. Positive impacts would come from optimizing the shipment modes in line with customer needs and cost-effectiveness.

# %% [markdown]
# #### Chart - 3

# %% [markdown]
# ####  Average Freight Cost

# %%
# Chart - 3 visualization code
data['Freight Cost (USD)'] = pd.to_numeric(data['Freight Cost (USD)'], errors='coerce')

# Assuming `data` is a DataFrame that has already been loaded and contains 'Freight Cost (USD)'
avg_freight_cost = data['Freight Cost (USD)'].mean()


# Creating the figure and axis
fig, ax = plt.subplots(1, 1, figsize=(18,10))

# Plotting the histogram of the Freight Cost (USD)
sns.histplot(x='Freight Cost (USD)', data=data, ax=ax, kde=True, bins=30, color='#4d148c')

# Adding chart styling
ax.set_title('Freight Cost Distribution', fontsize=18)
ax.set_xlabel('Freight Cost (USD)', fontsize=14)
ax.set_ylabel('Frequency', fontsize=14)

# Adjusting layout
plt.tight_layout()

# Displaying the plot
plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize=(18, 10))
sns.histplot(data['Freight Cost (USD)'],bins=20,kde=True,ax=ax)
plt.title('Freight Cost Distribution')
plt.xlabel('Freight Cost (USD)', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  A histogram is great for showing the spread and frequency of continuous data like freight costs. It helps identify if the data is skewed, if there are outliers, or if it follows a normal distribution. This gives a clear visual sense of how freight costs are distributed across the dataset.
#
#   Including the KDE curve helps to smooth the histogram and better highlight the underlying distribution. It’s useful when you want to see the overall shape of the data, which can be particularly helpful if there are multiple peaks or a skewed distribution.
#
#   The use of a histogram is a good decision to explore this type of data because it visually breaks down how frequent certain ranges of freight costs are and allows for better understanding of the general pattern in the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **insight**
#
# The analysis reveals that the average freight cost is 11,076.78, with a
# right-skewed distribution indicating that most shipments are below
# this average. While lower-cost consignments are more frequent, there are a
# few high-value shipments that significantly influence the average.
# Very few shipments exceed $50,000, suggesting that high-cost logistics are less common.
# This insight can help optimize logistics strategies by identifying the factors
# driving higher costs and exploring ways to reduce them.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **positive**
#
# **Cost** **Optimization**:
# By analyzing the distribution of freight costs, businesses can identify whether they’re spending disproportionately on freight in certain segments.
#
# **Targeted** **Decision**-**Making**: Understanding freight cost trends enables businesses to make more data-driven decisions when choosing suppliers, carriers, or transportation methods. If the majority of the costs are clustered around a high value, a business might decide to reevaluate its freight providers or optimize its order fulfillment strategy.
#
# **Forecasting** **and** **Budgeting**: The average freight cost (if included in the analysis) can serve as a benchmark for forecasting future logistics expenses. This is critical when planning budgets or setting pricing for products, ensuring that the cost of goods sold (COGS) is accurately aligned with expenses.
#
# **Negative**
#
# **Identifying** **Unpredictable** **Costs**: If the histogram shows a highly variable or skewed distribution of freight costs, it might signal inefficiency or unpredictability in the shipping process. If costs are highly volatile, this could lead to difficulties in budgeting or unexpected surges in expenses, which could negatively impact the business’s profitability.
#
# **Overemphasis** **on** **Average** **Cost**: Relying too heavily on the average freight cost without considering the variability or outliers in the data could lead to complacency. If the business focuses only on the average cost and ignores high-cost outliers or large fluctuations in shipping rates, it could fail to identify underlying issues that could result in higher costs over time.

# %% [markdown]
# #### Chart - 4

# %% [markdown]
# #### Line Item Quantity Distribution

# %%
# Chart - 4 visualization code
# Counting the frequency of each Line Item Quantity value
#count_line_quantity = data['Line Item Quantity'].value_counts()

# Creating the figure and axis
fig, ax = plt.subplots(1, 1, figsize=(18, 10))

# Plotting the histogram of the Line Item Quantity
sns.histplot(x='Line Item Quantity', data=data, ax=ax, kde=True, bins=30, color='#ff6600')

ax.set_title('Line Item Quantity Distribution', fontsize=16)
ax.set_xlabel('Line Item Quantity', fontsize=14)
ax.set_ylabel('Frequency', fontsize=14)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a histogram with a KDE (Kernel Density Estimate) for visualizing the distribution of "Line Item Quantity" values because it provides a clear view of how frequently different quantities appear in the data.
#
# A histogram helps us understand the distribution of values in a specific column, in this case, the "Line Item Quantity." It shows the frequency of each quantity, allowing us to spot trends, clusters, or outliers.
#
# The Kernel Density Estimate smooths the histogram, offering a clearer picture of the data's overall shape, particularly when the quantity values might have variability that a regular histogram might not fully capture. The KDE curve makes it easier to see the underlying distribution without being too cluttered by individual bars.
#
# This combination allows you to explore the data in a detailed yet readable way. If you want to understand trends over time or investigate specific values, the chart offers a flexible starting point for deeper analysis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# If most of the data is clustered around smaller quantities, it could suggest that the typical transaction involves a small number of items.
# If there’s a sharp peak at a quantity like 1, it could indicate that most transactions are individual item sales.
# If you observe a gradual decline as quantities increase, this might suggest that larger transactions (with more items) are less frequent.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive**
#
# If the distribution of "Line Item Quantity" shows trends in frequently purchased quantities, it can inform demand forecasting.
# Understanding common purchase quantities can also help tailor pricing strategies or promotional offers. If larger quantities are popular, bulk discounting or bundling strategies could be employed to increase sales, or pricing structures could be adjusted accordingly to match customer demand patterns.Insights from the distribution can guide sales teams on focusing efforts around high-frequency quantities. This could also lead to more targeted marketing campaigns that highlight the most common quantity bands, improving conversion rates.
#
# **Negative**
#
# If a certain "Line Item Quantity" value is extremely low or shows a significant drop in frequency, it could indicate that customers aren’t purchasing in those ranges. This could suggest inefficiencies in how products are being offered or marketed. For example, if a particular quantity (e.g., small quantities) shows a very low frequency, it might mean customers are not interested in buying in that quantity and prefer larger purchases or bundles. If a business is focusing on this, it could lead to poor sales and inventory mismanagement.If the histogram reveals a mismatch between the most frequent quantities purchased and the current stock levels, this could result in overstocking and associated carrying costs, which can hurt profitability.If the data reveals that certain quantities (or ranges) are not attracting customers, it could suggest a misalignment in product offerings, pricing strategies, or market segmentation. This insight may lead to the reevaluation of marketing tactics, product configurations, or sales channels to address customer preferences more effectively.

# %% [markdown]
# #### Chart - 5

# %% [markdown]
# #### Vendors with highest orders

# %%
# Chart - 5 visualization code

fig, ax = plt.subplots(figsize=(18, 10))

# Resetting the index to avoid potential duplicate index issues
data = data.reset_index(drop=True)


sns.countplot(x = 'Vendor',order=data['Vendor'].value_counts().nlargest(20).index ,data = data , color = "gray")
plt.title('Count of Shipment By Country',fontsize=14)
plt.xlabel('Analyzing vendor Count', fontsize=14)
plt.ylabel('frequancy')
plt.xticks(rotation=90)

plt.tight_layout()
plt.show()

# %%
# Chart - 5 visualization code

fig, ax = plt.subplots(figsize=(18, 10))

sns.countplot(x = 'Vendor', data=data, color = "gray") #removed extraneous data=['ID']
plt.title('Count of Shipment By Country',fontsize=14)
plt.xlabel('Analyzing vendor Count', fontsize=14)
plt.ylabel('frequancy')
plt.xticks(rotation=90)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# a countplot of "Vendor" with the top 5 most frequent vendors based on their shipment counts, is highly relevant for analyzing certain business insights. This countplot is effective because it visualizes the frequency of shipments per vendor, giving an easy-to-understand picture of the distribution of suppliers. By focusing on the top vendors, it helps to highlight where business impact (positive or negative) is being driven, offering actionable insights into procurement, supply chain risk management, and vendor relationship optimization.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# the key insights from the chart revolve around identifying the dominant vendors, understanding supply chain risks, finding opportunities for vendor negotiation, and ensuring that there’s no over-reliance on one supplier. This analysis could lead to more informed decisions on supply chain diversification, vendor management, and strategic sourcing.
#
# The bar chart illustrates the top vendors based on the number of orders.
# SCMS from RDC stands out with a significantly higher order count
# (over 5000) compared to other vendors.
# The remaining vendors, such as Ogenics, Ltd and S.
# BUYS WHOLESALER, have relatively low order
# counts (around 1000 or less), showing a vast disparity.
# This suggests that SCMS from RDC plays a dominant role in procurement,
# while the other vendors are less active in comparison.''')

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive** **Impact**:
# Insights from vendor performance analysis can help streamline vendor relationships, reduce supply chain risks, and optimize procurement strategies.
#
# **Negative** **Impact**: However, if not carefully managed, over-reliance on a few vendors can lead to vulnerabilities, higher costs, and slower growth due to lack of diversification and competition.
#
#  while the insights can certainly help drive a positive business impact through stronger vendor relations and better risk management, they also highlight potential areas where businesses need to diversify their vendor base and ensure that they aren’t overly dependent on any single supplier. Ignoring these risks could lead to negative growth due to supply chain disruptions, higher costs, and missed opportunities for improvement.

# %% [markdown]
# #### Chart - 5 - BAR PLOT (#DAYS IN DELIVERED)

# %%
data['Delivered to Client Date'] = pd.to_datetime(data['Delivered to Client Date'], errors='coerce')
data['Scheduled Delivery Date'] = pd.to_datetime(data['Scheduled Delivery Date'], errors='coerce')
data['days']=(data['Delivered to Client Date']-data['Scheduled Delivery Date']).dt.days

# %%
data[data['days']>0].shape  #dealys
# Out:
# (1186, 34)

# %%
data[data['days']<=0].shape   #advance and same day
# Out:
# (9138, 34)

# %%
plt.figure(figsize=(8,8))
plt.plot(data['days'])
plt.xlabel('#days(delay/advance)')
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.kdeplot(data=data['days'])
plt.xlabel('#days(delay/advance)')
# Out:
# Text(0.5, 0, '#days(delay/advance)')

# %% [markdown]
# 1. Why did you pick the specific chart?

# %% [markdown]
# A line plot is particularly useful when you want to show the relationship between two continuous variables or track changes over time. In the context of "days" (which includes both delays and advances),

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The line chart of delivery performance reveals significant fluctuations in the number of days taken for delivery, with values ranging from highly negative to considerably positive. This indicates that while some deliveries were completed much earlier than the scheduled date, others experienced substantial delays. The presence of extreme negative values suggests possible early deliveries, whereas the spikes in the positive range highlight recurring delays in the delivery process. Additionally, clusters of data points around the zero line indicate periods of relatively on-time deliveries. However, the irregular patterns and sudden deviations suggest inconsistencies in the supply chain or potential data quality issues, such as incorrect date entries or missing information. These findings emphasize the need for further investigation into the root causes of delivery delays and early shipments to optimize scheduling and improve overall efficiency.

# %% [markdown]
# 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights found will definitely help for a positive business impact. The insight that there are recurring delays and early deliveries indicates potential inefficiencies or bottlenecks in the supply chain. By investigating the underlying causes (e.g., production delays, transportation issues, or poor demand forecasting), the business can take corrective action to optimize processes and ensure that products are delivered closer to the expected timeframe.
# Positive impact: Reducing delays and minimizing early deliveries can enhance customer satisfaction and operational efficiency

# %% [markdown]
# #### Chart - 6

# %% [markdown]
# # **Bi-Variate Analysis**

# %% [markdown]
# #### Average Weight by Shipment Mode

# %%
# Chart - 6 visualization code

# Assuming `data` is already defined and contains the necessary columns

fig, ax = plt.subplots(1, 1, figsize=(10, 10))

# Convert 'Weight (Kilograms)' to numeric values (coerce errors)
data['Weight (Kilograms)'] = pd.to_numeric(data['Weight (Kilograms)'], errors='coerce')

# Grouping the data by 'Shipment Mode' and calculating the average weight
avg_weight_by_mode = data.groupby('Shipment Mode')['Weight (Kilograms)'].mean().reset_index()

# Creating a bar plot with the grouped data
sns.barplot(data=avg_weight_by_mode, x='Shipment Mode', y='Weight (Kilograms)', color="skyblue", ax=ax)

# Setting the title and axis labels
ax.set_title('Average Weight by Shipment Mode')
ax.set_xlabel('Shipment Mode')
ax.set_ylabel('Weight (Kilograms)')

# Rotate x-axis labels (optional, depending on length)
plt.xticks(rotation=90)

# Adjust layout to avoid label clipping
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The bar plot was chosen because it is straightforward, easy to interpret, and highly effective for comparing averages across multiple categories (shipment modes in this case). The insights derived from this chart could guide logistics decisions, cost optimizations, and improvements in the shipping process, ultimately helping to enhance overall business performance and operational strategy.
# A bar plot is ideal for comparing the average weight of shipments across different shipment modes. The bars make it easy to compare different categories side-by-side. This is particularly useful when you want to visually identify which shipment mode handles heavier or lighter shipments on average.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **insight**
#
# The bar plot reveals that air transport handles relatively lighter shipments,
# with an average weight between 1000 to 1500 kg,
# likely due to speed and cargo limitations.
# In contrast, truck transport carries significantly heavier shipments,
# averaging 6500 kg,
# while ocean and rail shipments have even higher averages, around
# 6800 kg and 7000 kg, respectively.
# This indicates that air is used for lighter, more urgent goods,
# while ground and sea are preferred for bulkier cargo

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive** **Impact**: The insights from the average weight by shipment mode chart can help optimize shipping costs, improve operational efficiency, and ensure better strategic planning. These improvements can lead to reduced costs, better customer satisfaction, and stronger supplier relationships, contributing to long-term business success.
#
# **Negative** **Impact**: If the insights reveal inefficiencies (such as over-reliance on air freight for heavy items or misalignment between product weight and shipment mode), the business could incur higher logistics costs, operational inefficiencies, and potential disruptions. Failure to act on these insights could result in negative growth due to increased expenses and reduced competitive advantage.

# %% [markdown]
# #### Chart - 7

# %% [markdown]
# #### Delivery Delays by Shipment Mode

# %%
# Chart - 7 visualization code
data['Delivered to Client Date'] = pd.to_datetime(data['Delivered to Client Date'])
data['Scheduled Delivery Date'] = pd.to_datetime(data['Scheduled Delivery Date'])
data['Delay_Days'] = (data['Delivered to Client Date'] - data['Scheduled Delivery Date']).dt.days

#fig,ax = plt.subplots(1,1,figsize= (18,10))
sns.barplot(x=data['Shipment Mode'], y=data['Delay_Days'], data=data, palette= "viridis")
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-53-cefba815c51a>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=data['Shipment Mode'], y=data['Delay_Days'], data=data, palette= "viridis")

# %%
# Ensure the columns are in datetime format
data['Delivered to Client Date'] = pd.to_datetime(data['Delivered to Client Date'])
data['Scheduled Delivery Date'] = pd.to_datetime(data['Scheduled Delivery Date'])

# Calculate Delay in Days
data['Delay_Days'] = (data['Delivered to Client Date'] - data['Scheduled Delivery Date']).dt.days

# Create the bar plot
plt.figure(figsize=(18, 10))
data['Shipment Mode'] = data['Shipment Mode'].str.strip().str.lower()
data.drop_duplicates(subset=['Shipment Mode', 'Delay_Days'], keep='first', inplace=True)
sns.barplot(x='Shipment Mode', y='Delay_Days', data=data, color="gray") # Changed avg_delay_by_mode to data

#sns.barplot(x='Shipment Mode', y='Delay_Days', data=avg_delay_by_mode, color="gray")

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The **bar** **plot** was chosen for this visualization because it effectively communicates the relationship between the shipment mode and the delay in days
# a **bar** **plot** is a suitable choice to understand how different shipment modes are performing in terms of delivery delays, making it both informative and visually

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **insight**
#
# The bar plot presents delivery delays by shipment mode.
# Air shipments show a slight delay close to zero days, indicating they are typically on time.
# Truck shipments experience moderate delays of around 10 days on average.
# Air charter shows the most significant delays, exceeding 15 days,
# while ocean transport faces delays just under 5 days.
# This suggests that air charters are the least
# reliable in terms of timeliness, while standard
# air shipments are the most punctual.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **positive** **impact**
#
# **Resource** **Allocation**: By understanding the average weight of shipments across different shipment modes, the business can better allocate resources.
#
# **Optimizing** **Shipping** **Costs**: Shipment weight directly affects shipping costs. If a particular shipment mode consistently carries heavier shipments, the company can assess whether this mode is the most cost-efficient.
#
# **Supply** **Chain** **Strategy**: Identifying which shipment modes carry heavier shipments can help with refining supply chain strategies. For example, modes that carry lighter items may need less handling, less storage, or different inventory management strategies than those that carry heavier items.
#
# **Negative** **impact**
# Imbalance in Shipment Mode Weight Distribution: If one or more shipment modes are found to consistently carry much heavier items, it could suggest inefficiency in the logistics network.
#
# **Underutilization** **of** **Lighter** **Modes**: If lighter shipment modes (e.g., air freight, courier services) are underutilized for heavier items, this could indicate a lack of coordination between business units or operational inefficiencies
#
# **Customer** **Segmentation** **Issues**: If the average weight for a specific shipment mode is very low, it may suggest that lighter items are being shipped through less efficient modes.

# %% [markdown]
# #### Chart - 8

# %% [markdown]
# #### Freight Cost In Comparison to Weight

# %%
# Chart - 8 visualization code
plt.figure(figsize=(10,10))

data = data.reset_index(drop=True) #Reseting the index to avoid duplicate labels

sns.scatterplot(data=data, x='Weight (Kilograms)', y='Freight Cost (USD)',color='#4d148c')

plt.title('Freight Cost In Comparison to Weight')
plt.xlabel('Weight(kilograms)')
plt.ylabel('Freight cost(USD)')
plt.xticks(rotation=90)
plt.yticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'data' is your DataFrame
plt.figure(figsize=(10,10))
data = data.reset_index(drop=True) #Reseting the index to avoid duplicate labels

sns.scatterplot(data=data, x='Weight (Kilograms)', y='Freight Cost (USD)', color='#4d148c')

plt.title('Freight Cost In Comparison to Weight')
plt.xlabel('Weight (Kilograms)')
plt.ylabel('Freight Cost (USD)')
plt.xticks(rotation=90)
plt.yticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **scatter** **plot** to visualize the relationship between "Weight (Kilograms)" and "Freight Cost (USD)" in your data. The reason for choosing this chart is likely to explore how changes in weight might influence the cost of freight. Scatter plots are great for this type of analysis because they help in identifying trends, clusters, outliers, and correlations between two continuous variables.
#
# Scatter plots are ideal for visualizing relationships between two continuous variables, such as weight and freight cost.
# They allow you to quickly assess whether there's a linear or non-linear relationship between the two variables.
#
# By using this scatter plot, you're likely trying to uncover whether heavier items tend to result in higher freight costs and whether the relationship is linear or exhibits any other patterns.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **insight**
#
# The scatter plot illustrates the relationship between
# freight cost and weight for a set of shipments.
# The general trend is that as the weight of a shipment increases,
# so does the freight cost.
# However, there is also a degree of variability around this trend, as evidenced by
# the scatter of the data points. This suggests that factors other than weight,
# such as distance, shipment mode, or item type, may also influence freight costs.
# Additionally, the plot reveals a few potential outliers,
# which could be due to unusual shipments or errors in the data.
# Overall, the scatter plot provides a visual representation of
# the relationship between freight cost and weight,
# highlighting the general trend while also indicating the
# presence of additional factors that may affect pricing.''')

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **positive** **impact**:
#
# If there’s a visible positive correlation between weight and freight cost, it can help businesses predict and plan for shipping expenses based on product weight. By forecasting shipping costs more accurately, businesses can adjust pricing strategies, optimize supply chains, and improve cost management.
# the freight cost increases steadily with weight, you might decide to introduce tiered pricing based on weight ranges. This would allow the business to pass on shipping costs in a fair manner to customers, protecting your margin.
# In some cases, you could also negotiate better shipping deals with carriers by presenting data on average freight costs related to weight, which could help in securing discounts.
# Analyzing the trend might highlight inefficiencies (e.g., unusually high freight costs for a certain weight range) that could lead to operational changes. For example, you could identify opportunities for consolidation of shipments or more efficient inventory management to reduce overall costs.
#
# **Negative** **impact**:
#
# If the scatter plot shows that freight costs increase disproportionately with weight (in a non-linear way), this could lead to higher-than-expected shipping expenses for your business, particularly if the business ships a lot of heavy item.
# If your pricing model does not account for the sharp increase in shipping costs, your profit margins could be eroded, leading to negative growth. Businesses would need to raise prices to maintain profitability, which could drive away price-sensitive customers.
# If there are outliers in the data—e.g., some shipments that are much heavier than others but incur disproportionately high costs—this could signal inefficiencies in your logistics chain. It might be the result of poor route optimization or outdated contracts with carriers.
# Such inefficiencies can lead to increased costs and a negative impact on profitability. Businesses might need to dive deeper into the logistics process to identify and resolve these outliers.
# If the plot suggests that freight costs increase steadily without much variation for different weights, it could imply that your business is not realizing economies of scale when shipping heavier products. Larger shipments might not be priced more efficiently, affecting growth potential.
# If this trend is pervasive across your shipping operations, you may need to reassess your logistics contracts or negotiate more favorable terms to benefit from bulk pricing.
#
# **Conclusion**:
# if the scatter plot reveals a positive correlation, the business can use that information to optimize pricing, manage costs more efficiently, and make informed decisions. However, if the relationship between weight and freight cost is disproportionately high, or if there are significant outliers, these could signal areas where costs are spiraling and need to be addressed. Without addressing these inefficiencies, the business might experience increased operational costs, which could limit growth or lead to negative financial outcomes.

# %% [markdown]
# #### Chart - 9

# %% [markdown]
# #### Total Shipments Over Time

# %%
# Chart - 9 visualization code
# Convert 'Shipment_Date' to datetime, filling missing values appropriately
#data['Shipment_Date'] = pd.to_datetime(data['PQ First Sent to Client Date'].fillna(data['Scheduled Delivery Date']))

data['PQ First Sent to Client Date'] = pd.to_datetime(data['PQ First Sent to Client Date'], errors='coerce')
data['Scheduled Delivery Date'] = pd.to_datetime(data['Scheduled Delivery Date'], errors='coerce')

# Create a new 'Shipment_Date' column, prioritizing 'PQ First Sent to Client Date'
data['Shipment_Date'] = data['PQ First Sent to Client Date'].fillna(data['Scheduled Delivery Date'])

# Set 'Shipment_Date' as index
data = data.set_index('Shipment_Date')

# Resample the data by month and count the number of shipments
shipments_over_time = data.resample('M').size()

# Create figure and axes
fig, ax = plt.subplots(figsize=(18, 10))

# Create an area chart using fill_between
ax.fill_between(shipments_over_time.index, shipments_over_time.values, color='#ff6600', alpha=0.6)

# Set the title for the plot
ax.set_title('Total Shipments Over Time', fontsize=16)
plt.suptitle('Tracking the number of shipments each year', fontsize=14, y=1.05)

# Apply tight layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# <ipython-input-57-a081d5b17201>:5: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['PQ First Sent to Client Date'] = pd.to_datetime(data['PQ First Sent to Client Date'], errors='coerce')
# <ipython-input-57-a081d5b17201>:15: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   shipments_over_time = data.resample('M').size()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# a visual representation of the shipment data over time, with a focus on the count of shipments per month. The chart you’ve chosen—a filled area chart—is well-suited for this purpose for a few reasons. An area chart provides an easy way to visualize changes in the total number of shipments over time. You can clearly see patterns, peaks, and dips, which can help you identify trends like seasonal fluctuations or any other significant shifts in shipment activity.
#
# the area chart was picked to give an intuitive, visual representation of how the number of shipments changes over time, which is the key insight you seem to want to convey. It effectively showcases trends and seasonality.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **insight**
#
# The chart depicts the total number of shipments over time,
# highlighting trends and potential seasonal patterns from 2006 to 2016.
# We observe an initial gradual increase in shipments between 2006 and 2009,
# followed by notable fluctuations in volume from 2010 onwards.
# Peaks are visible at multiple intervals,
# indicating potential periods of high demand,
# while some sharp drops suggest potential off-seasons or disruptions.
# The most significant activity occurred around 2013-2014,
# where shipment counts approached or exceeded 250.
# After 2015, there's a visible decline, possibly indicating a
# slowdown in operations or changing market conditions.
# This pattern may reflect seasonal or
# business-cycle-driven variations in shipment volumes.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive**: A consistent rise in shipments month over month may indicate an effective business strategy or growing customer demand. This could prompt more investment in production, logistics, or customer acquisition efforts.
#
# **Negative**: A dip in shipments in certain months could signal an issue like product delays or a seasonal downturn in demand. This could be troubling if not addressed, as it might cause fluctuations in cash flow or strain operations if the company is unable to scale back production during slower months.
#
# Conclusion:
# This chart can be a powerful tool for identifying both growth opportunities and challenges. Positive trends can drive investment and resource allocation to areas of strength, while negative trends should prompt deeper investigation into the underlying causes and potential solutions.

# %% [markdown]
# #### Chart - 10

# %% [markdown]
# #### Highest Paying Countries based on Freight Cost

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as mtick

# Convert 'Freight Cost (USD)' to numeric, forcing non-numeric values to NaN
data['Freight Cost (USD)'] = pd.to_numeric(data['Freight Cost (USD)'], errors='coerce')

# Fill missing values with 0
data['Freight Cost (USD)'] = data['Freight Cost (USD)'].fillna(0)

# Ensure 'Freight Cost (USD)' is an integer type
data['Freight Cost (USD)'] = data['Freight Cost (USD)'].astype(int)

# Get the top 10 countries by total freight cost
top_10_countries = data.groupby('Country')['Freight Cost (USD)'].sum().nlargest(10).reset_index()

# Create the bar plot
fig, ax = plt.subplots(figsize=(18, 10))

# Create barplot for top 10 countries by freight cost
sns.barplot(x='Country', y='Freight Cost (USD)', data=top_10_countries, palette="viridis", ax=ax)

# Format the y-axis with commas
ax.yaxis.set_major_formatter(mtick.StrMethodFormatter('{x:,.0f}'))

# Set the title of the chart
ax.set_title('Highest Paying Countries based on Freight Cost', fontsize=16)

# Apply tight layout to prevent overlap
plt.tight_layout()

# Display the plot
plt.show()
# Out:
# <ipython-input-58-3ca62269b218>:23: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Country', y='Freight Cost (USD)', data=top_10_countries, palette="viridis", ax=ax)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A **bar** **plot** is an effective way to compare quantities across different categories—in this case, the freight costs for different countries. The length of each bar directly represents the total freight cost, making it easy to visually compare countries.
# Focusing on the top 10 countries allows you to zoom in on the highest contributors to freight costs without getting lost in the potentially large number of countries in the dataset. This narrows down the data to what is most impactful.
# This chart serves as a powerful visualization for identifying and comparing the countries that contribute the most to freight costs, which is likely the key insight you're after

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **insight**
#
# The bar plot compares the distribution of freight costs across different shipment modes.
# It shows that Air Charter has the highest median freight cost,
# followed by Truck and Sea. The interquartile range (IQR) for Sea is the smallest,
# indicating a more consistent freight cost compared to other modes.
# The outlier for Truck suggests a significantly higher freight cost in one or more months.
# Overall, the plot highlights the variability in freight costs
# across different modes and identifies Air Charter as the most expensive option.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive** **Impact**:
#
# **Targeted** **Decision**-**Making**:
# By identifying the countries contributing the highest freight costs, businesses can tailor their strategies to optimize operations in those regions. For example, if certain countries are driving up costs due to logistical inefficiencies, this insight could help target improvements, such as negotiating better shipping contracts or optimizing supply chains.
# It could also inform decisions about market expansion or the allocation of resources. If a country is a high contributor to freight costs, it might indicate a market with high demand, potentially leading to more investment in that region.
#
# **Cost** **Optimization**:
# This information enables businesses to prioritize cost-saving initiatives in specific countries or regions where the freight costs are disproportionately high. Companies can explore alternative shipping methods, negotiate better rates with carriers, or even adjust the supply chain to reduce unnecessary costs.
#
# **Strategic** **Partnerships**:Understanding where the highest freight costs occur may reveal opportunities for partnerships with local logistics providers or manufacturers in those countries. Building closer relationships can drive down costs through more efficient operations or economies of scale.
#
# **Negative** **impact**:
#
# **Over**-**reliance** **on** **High** **Freight** **Countries**:
# If a business is overly reliant on countries with high freight costs, the impact on profitability can be negative, especially if those costs are not managed effectively. As the data suggests, the countries driving up the freight costs might not necessarily be the ones that offer the highest returns on investment, leading to inefficient use of resources and a negative bottom line.
#
# **Ignoring** **Lower**-**Cost** **Regions**:If businesses focus solely on the high-paying countries (i.e., those with high freight costs), they might overlook countries where the costs are lower but the business potential is just as high. A strategy that’s too focused on the "top 10" countries might miss out on more sustainable, cost-effective growth opportunities in other regions.
#
# **Logistical** **Risk**:Relying on countries with high freight costs could expose a company to logistical risks. If a country is already expensive to operate in, external factors (e.g., geopolitical instability, fuel price fluctuations, regulatory changes) could drive those costs even higher, leading to unanticipated financial stress.
#
# Conclusion:In the best-case scenario, understanding which countries drive freight costs enables smarter, more focused decision-making that can lead to cost optimization and targeted business growth. However, if not approached with caution, overemphasis on these high-cost regions could reduce profitability or lead to missed opportunities.

# %% [markdown]
# #### Chart - 11

# %% [markdown]
# # **Multi-Variate Analysis**

# %% [markdown]
# #### Freight Cost by Country, Shipment Mode, and Vendor

# %%
# Chart - 11 visualization code
top_10_countries = data['Country'].value_counts().nlargest(10).index

top_10_data = data[data['Country'].isin(top_10_countries)]
# Reset the index of top_10_data
top_10_data = top_10_data.reset_index(drop=True)

fig, ax = plt.subplots(figsize=(18, 10))


sns.scatterplot(x='Weight (Kilograms)', y='Freight Cost (USD)', hue='Country',  size='Weight (Kilograms)',  style='Shipment Mode',  sizes=(250, 1000),  data=top_10_data,  palette="viridis", ax=ax,legend = False)

# Add title and labels, subtitle='Tracking the number of shipments each month'
plt.title('Freight Cost vs Weight by Shipment Mode and Top 10 Countries')
plt.xticks(rotation=90)
plt.yticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **scatter** **plot** with multiple dimensions (weight, freight cost, country, shipment mode)—was selected for a few key reasons, all aimed at providing a clear and insightful visual representation of the relationship between freight cost, weight, and other variables across different countries.
#
# The **scatter** **plot** was chosen because it visually connects multiple key variables—freight cost, weight, country, and shipment mode—helping you identify trends, inefficiencies, and opportunities. It provides a comprehensive view of how freight costs correlate with weight across the top 10 countries, highlighting the role of shipment mode and country in these costs.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **insight**
#
# The scatter plot illustrates the relationship between freight cost
# and weight for a set of shipments across different modes and top 10 countries.
# The general trend is that as the weight of a shipment increases, so does the freight cost.
# However, there is also a degree of variability
# around this trend, as evidenced by the scatter of the data points.
# This suggests that factors other than weight, such as distance,
# shipment mode, or country, may also influence freight costs.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive** **outcome**:
#
# Businesses can consider alternative shipment methods (e.g., switching from air to sea) for heavier shipments to reduce freight costs without compromising delivery time too much.
#
# The business could prioritize using cheaper shipment modes in specific countries, reducing overall transportation costs, improving efficiency, and enhancing profitability.
#
# Businesses can increase their focus on more profitable markets, optimizing shipping strategies and pricing accordingly.
#
# **Negative** **outcome**: High freight costs could erode profit margins, especially for businesses shipping heavy products to these countries. In this case, continued reliance on costly shipment methods without exploring cheaper alternatives could lead to negative financial growth.
#
# The business might be paying more for shipping than necessary in these regions. If not addressed, this can result in inefficiencies and wasteful spending, negatively affecting the bottom line.
#
# Relying too much on an expensive shipment mode can increase overall transportation costs, reducing profitability. Businesses may need to adopt more flexible, cost-effective shipping solutions depending on the region and weight.

# %% [markdown]
# #### Chart - 12

# %% [markdown]
# #### Line Item Value in comaprison with Freight Cost by Vendor and Shipment Mode

# %%
# Chart - 12 visualization code
fig, ax = plt.subplots(figsize=(16, 10))

# Scatter plot
sns.scatterplot(
    x='Line Item Value',
    y='Freight Cost (USD)',
    hue='Vendor',
    style='Shipment Mode',
    data=data,
    ax=ax,
    palette="viridis",
    legend=False
)
sns.regplot(
    x='Line Item Value',
    y='Freight Cost (USD)',
    data=data,
    scatter=False,
    ax=ax,
    color='gray',
)

# Apply chart styling
plt.title('Line Item Value in comaprison with Freight Cost by Vendor and Shipment Mode')
plt.yticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# a **scatter** **plot** combined with a regression line to explore the relationship between "Line Item Value" and "Freight Cost (USD)." Here's why I would choose this specific chart design
#
# It’s a great way to visualize the individual data points and see how "Line Item Value" and "Freight Cost" are distributed. By using hue='Vendor' and style='Shipment Mode', you can quickly identify if there are any patterns or clusters based on vendor or shipment mode.
# This visualizes the data in a way that lets you spot outliers, trends, and correlations in a clear, intuitive manner.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **insight**
#
# The scatter plot illustrates the relationship between the line item value and freight cost for a set of shipments,
# considering the effects of vendor and shipment mode.
# The general trend is that as the line item value increases,
# so does the freight cost. However, there is also a degree of variability around this trend,
# as evidenced by the scatter of the data points.
# This suggests that factors other than line item value, such as vendor,
# shipment mode, or other variables not included in the plot, may also influence freight costs.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **positive** **impact**
#
# If you notice that certain vendors consistently show a low "Freight Cost" relative to "Line Item Value," that suggests more cost-effective shipping practices or better pricing models.
# Positive outcome: The business could strategically increase orders with those vendors to optimize freight costs and boost overall profitability.
# Optimization of Shipment Modes:
#
# If the chart reveals that certain shipment modes (e.g., air, sea, truck) are more efficient in relation to freight cost and line item value, the business can focus on optimizing shipping decisions.
#
# **Negative** **impact**
#
# If the chart reveals that certain vendors or shipment modes are associated with disproportionately high freight costs for lower-value items, it indicates inefficiencies in the supply chain.
# Negative outcome: These inefficiencies could eat into profit margins, and if this trend is widespread, it could indicate a systemic problem. It may be necessary to renegotiate with vendors or reassess shipment methods for low-value products.
# Poor Vendor Performance:
#
# If some vendors appear to have high freight costs relative to the line item values, it might signal poor vendor performance, such as inflated shipping prices, delays, or suboptimal logistical practices.
# Negative outcome: If these vendors are critical to the business, maintaining the relationship could result in long-term negative financial impact. The business might need to reconsider those partnerships or explore alternative vendors.

# %% [markdown]
# #### Chart - 13

# %% [markdown]
# **Freight Cost by Shipment Mode, Fulfill Via, and Country**

# %%
# Chart - 13 visualization code
fig, ax = plt.subplots(1, 1, figsize=(18, 10))

# Resetting index to prepare the data (if necessary)
plot_data = data.reset_index()

# Create the box plot
sns.boxplot(
    x='Shipment Mode',
    y='Freight Cost (USD)',
    hue='Fulfill Via',  # Add segmentation by fulfill method
    data=plot_data,  # Use the reset index data
    ax=ax,
    palette="viridis",
    showfliers=False  # Option to hide outliers
)

# Adding title and improving layout
plt.title('Freight Cost by Shipment Mode, Fulfill Via, and Country')
plt.yticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# a box plot for this chart because it is a great way to visualize the distribution of continuous variables (like Freight Cost (USD)) across different categorical groups (such as Shipment Mode and Fulfill Via).
# A box plot provides a clear summary of the distribution of data, showing the median, quartiles, and potential outliers. This is helpful when you want to compare freight costs between different shipment modes (e.g., air, sea, ground) or fulfillment methods (e.g., direct shipping, third-party logistics)

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **insight**
#
# The box plot compares the distribution of freight costs across different shipment modes,
# fulfillment vias, and countries.
# It shows that FedEx Ground has the highest median freight cost,
# followed by FedEx Express and FedEx Economy.
# The interquartile range (IQR) for FedEx Economy is the smallest,
# indicating a more consistent freight cost compared to other modes.
# he outliers for FedEx Ground and FedEx Express suggest significantly
# higher or lower freight costs in one or more months.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive** **Impact**: The box plot can help you optimize freight costs, streamline fulfillment strategies, detect outliers to improve operational efficiency, and identify potential regional opportunities.
#
#
# **Negative** **Impact**: High freight costs tied to specific shipment modes or fulfillment methods could lead to negative growth if left unchecked. Outliers, if not managed, could result in increased costs and poor customer satisfaction.
#
#
# Ultimately, leveraging these insights effectively can drive positive business outcomes. However, the data could also highlight areas of inefficiency or unsustainable practices that need immediate attention to avoid negative growth

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
import matplotlib.colors as mcolors # Import mcolors

colors = ['#4d148c', '#ff6600']

# Create the colormap
custom_cmap = mcolors.LinearSegmentedColormap.from_list('custom_cmap', colors)

numeric_columns = data.select_dtypes(include=np.number).columns # Define numeric_columns


correlation_matrix = data[numeric_columns].corr()

# Create a heatmap
fig,ax = plt.subplots(figsize=(18, 10))
sns.heatmap(correlation_matrix, annot=True, ax=ax,cmap= custom_cmap, fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap of Numeric Variables')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# a correlation heatmap—is great for visualizing the relationships between numeric variables in a dataset. It’s often used because it provides a clear, easily interpretable summary of how variables correlate with each other, highlighting areas of strong and weak correlations at a glance. The heatmap allows you to immediately see which variables are strongly correlated (positive or negative) with each other. It makes it easy to spot patterns in the data, like pairs of features that are highly correlated or even perfectly correlated.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **insight**
#
# The correlation heatmap reveals strong positive
# relationships between line item quantity and value,
# and a moderate positive correlation between weight and freight cost.
# Weaker positive correlations exist between line item insurance and freight cost.
# These findings suggest that the quantity and value of items,
# as well as weight, are significant factors influencing freight costs.
# the correlation heatmap is a powerful tool to identify relationships between key numeric variables. It helps you spot strong and weak relationships, detect potential multicollinearity issues, and understand how different logistics variables are interconnected, ultimately assisting in decision-making and optimization.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
numeric_columns = ['Line Item Value', 'Weight (Kilograms)', 'Freight Cost (USD)', 'Line Item Insurance (USD)', 'Line Item Quantity']

# Drop rows with missing values in the selected columns
df_pairplot =data[numeric_columns + ['Shipment Mode']].dropna()


# Create pair plot with shipment mode as hue
fig = sns.pairplot(df_pairplot,
                   hue='Shipment Mode',
                   palette="viridis",
                   diag_kind='kde',  # Kernel density estimate on the diagonal
                   plot_kws={'alpha': 0.7})  # Transparency of points

plt.figure().set_facecolor('#D3D3D3')

# Customize the appearance of each subplot
for ax in fig.axes.flatten():
    ax.set_facecolor('#D3D3D3')
    ax.grid(axis='both', linestyle='-', alpha=0.4)  # Light gridlines
    ax.set_axisbelow(True)

# Add a title to the entire figure
fig.fig.suptitle('Logistics Data Pair Plot', fontsize=18, fontweight='bold', fontfamily='serif')
fig.fig.subplots_adjust(top=0.95)

# Add custom insight text outside the plot
fig.fig.text(1.05, 0.85, 'Insight', fontsize=18, fontweight='bold', fontfamily='serif')
fig.fig.text(1.05, 0.67, '''
This pair plot reveals relationships among line item value, weight, freight cost,
and insurance costs across different shipment modes. Patterns can help identify
which factors most influence freight costs in logistics operations.
''', fontsize=12, fontfamily='serif')

fig.fig.patch.set_facecolor('#D3D3D3')
# Display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# the dataset you're working with, which includes numeric variables related to logistics (like "Line Item Value," "Weight (Kilograms)," and "Freight Cost"). Here’s why the pair plot is a great choice:
#
# A pair plot is excellent when you want to explore how multiple numeric variables relate to each other. By plotting every combination of numeric columns against each other, it gives a clear picture of their pairwise relationships, which is crucial for understanding correlations, trends, or clusters that could be hidden in the data

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This pair plot reveals relationships among line item value, weight, freight cost,
# and insurance costs across different shipment modes. Patterns can help identify
# which factors most influence freight costs in logistics operations.The different shipment modes are color-coded in the plot (via the hue parameter). This makes it easy to compare how the relationships between variable differ depending on the shipment mode. It provides insights into whether certain shipment modes are associated with higher or lower values in these metrics. the pair plot enables the visualization of relationships between different logistics factors and shows how shipment mode influences these relationships.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# The solution to optimize FedEx Logistics' operations involves using data insights to balance cost and delivery efficiency. By analyzing shipment modes, it was found that air transport incurs higher freight costs but offers faster delivery, making it suitable for time-sensitive, high-value goods. For heavier or low-value shipments, sea or ground transport should be prioritized to reduce costs. Additionally, identifying **key vendors and countries** with the highest shipment volumes enables better resource allocation. Addressing **delivery delays** through improved tracking and vendor management will enhance on-time performance, reduce costs, and improve overall customer satisfaction.
#
# Possible Solutions Based on Insights
#
# Optimization of Shipping Modes:
#
# Since air shipping is the dominant mode (61.4%), explore cost-effective alternatives like ocean or trucking where feasible to reduce expenses.
# Country-Specific Cost Analysis:
#
# Focus on countries with higher freight cost variability to identify potential inefficiencies or renegotiate contracts.
# Weight Distribution Strategy:
#
# Address clusters of low-weight shipments that may be driving up overall costs by consolidating them for better efficiency.
# Route and Distance Optimization:
#
# Utilize insights from the time series data to optimize delivery routes and avoid delays or cost spikes.
# Target High-Volume Regions:
#
# South Africa and other high-shipment countries should be analyzed for potential bulk shipping agreements to leverage economies of scale.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# This comprehensive analysis provides FedEx Logistics with actionable insights into their operations. By identifying the key factors driving costs, delays, and vendor performance, the company can implement targeted improvements to optimize its global supply chain. The univariate, bivariate, and multivariate analyses collectively offer a holistic understanding of the logistics landscape, enabling FedEx to enhance efficiency, reduce costs, and improve customer satisfaction across its operations.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
